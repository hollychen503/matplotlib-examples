# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# # Figures and Subplots

# %% [markdown]
# ## add_subplot()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1) # 2 行， 2列，第一个图
ax2 = fig.add_subplot(2, 2, 2) # 2 行， 2列，第2个图
ax3 = fig.add_subplot(2, 2, 3) # 2 行， 2列，第3个图

ax3.plot(np.random.standard_normal(50).cumsum(), color="black", linestyle="dashed" )

ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3 )
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal (30));
# Out:
# /Volumes/T5/source/python/jupyter-p3/venv/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /Volumes/T5/source/python/jupyter-p3/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## subplots

# %%
fig, axes = plt.subplots(2, 3)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.standard_normal(500), bins=50,color="black", alpha=0.5)

fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ## linestyle

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(np.random.standard_normal(30).cumsum(), color="black",linestyle="dashed",marker="o");

# %% [markdown]
# ## drawstyle

# %%
fig = plt.figure()
ax = fig.add_subplot()
data = np.random.standard_normal(30).cumsum()
ax.plot(data, color="black", linestyle="dashed", label="Default");
ax.plot(data, color="black", linestyle="dashed",
        drawstyle="steps-post", label="steps-post");
ax.legend()
